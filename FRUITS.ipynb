# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
# Load the Xception model
# https://keras.io/api/applications/xception/
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
# Default Image Size for Xception
image_size = (299, 299)

# %%
# Refactor above steps into reusable function
def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3)[0])

# %%
image_path = os.path.join("..", "Images", "banana.jpg")
predict(image_path)
# Out:
# Predicted: [('n07753592', 'banana', 0.99682546), ('n03532672', 'hook', 0.0003636068), ('n01945685', 'slug', 0.0003166044)]

# %%
image_path = os.path.join("..", "Images", "apple.jpg")
predict(image_path)
# Out:
# Predicted: [('n07742313', 'Granny_Smith', 0.8480879), ('n07720875', 'bell_pepper', 0.007033588), ('n07768694', 'pomegranate', 0.006762423)]

# %%
image_path = os.path.join("..", "Images", "fig.jpg")
predict(image_path)
# Out:
# Predicted: [('n07753113', 'fig', 0.9513342), ('n02111129', 'Leonberg', 0.00042548747), ('n02412080', 'ram', 0.00040446295)]

# %%
image_path = os.path.join("..", "Images", "lemons.jpg")
predict(image_path)
# Out:
# Predicted: [('n07749582', 'lemon', 0.98804593), ('n07747607', 'orange', 0.004214649), ('n03062245', 'cocktail_shaker', 0.00014575574)]

# %%
image_path = os.path.join("..", "Images", "orange.jpg")
predict(image_path)
# Out:
# Predicted: [('n07747607', 'orange', 0.60794854), ('n07749582', 'lemon', 0.37323976), ('n03062245', 'cocktail_shaker', 0.00027959762)]

# %%
image_path = os.path.join("..", "Images", "strawberry.jpg")
predict(image_path)
# Out:
# Predicted: [('n07745940', 'strawberry', 0.9364423), ('n07753275', 'pineapple', 0.0012724408), ('n07613480', 'trifle', 0.0010907901)]

# %%
image_path = os.path.join("..", "Images", "pineapple.jpg")
predict(image_path)
# Out:
# Predicted: [('n07753275', 'pineapple', 0.9183361), ('n07747607', 'orange', 0.0023514782), ('n07745940', 'strawberry', 0.0012408276)]

# %%
image_path = os.path.join("..", "Images", "pomegranate.jpg")
predict(image_path)
# Out:
# Predicted: [('n07768694', 'pomegranate', 0.9872307), ('n07742313', 'Granny_Smith', 0.0033789233), ('n07745940', 'strawberry', 0.0019305181)]

# %%
image_path = os.path.join("..", "Images", "jackfruit.jpg")
predict(image_path)
# Out:
# Predicted: [('n07754684', 'jackfruit', 0.9670095), ('n12144580', 'corn', 0.0039665666), ('n13133613', 'ear', 0.00095329975)]

# %%
image_path = os.path.join("..", "Images", "broccoli.jpg")
predict(image_path)
# Out:
# Predicted: [('n07714990', 'broccoli', 0.8775671), ('n07715103', 'cauliflower', 0.025069477), ('n07714571', 'head_cabbage', 0.0032608293)]

# %%
image_path = os.path.join("..", "Images", "bellpepper.jpg")
predict(image_path)
# Out:
# Predicted: [('n07720875', 'bell_pepper', 0.96352214), ('n07717410', 'acorn_squash', 0.0017549869), ('n07718472', 'cucumber', 0.00071923033)]

# %%
image_path = os.path.join("..", "Images", "cucumber.jpg")
predict(image_path)
# Out:
# Predicted: [('n07718472', 'cucumber', 0.7084677), ('n07716358', 'zucchini', 0.26810178), ('n02321529', 'sea_cucumber', 0.0012970075)]
